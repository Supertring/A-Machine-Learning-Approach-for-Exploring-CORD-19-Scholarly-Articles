# %% [markdown]
# # Word Clouds for exploring clusters

# %%
import pandas as pd
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
import matplotlib.pyplot as plt

# %%
work_data = pd.read_csv('work_data.csv')
work_metadata = pd.read_csv('work_metadata.csv')

# %%
work_data.head()
# Out:
#                                                 text  word_count  \
# 0  surfactant protein d pulmonary host defense su...        3903
# 1  heme oxygenase carbon monoxide pulmonary medic...        3480
# 2  functional genomic functional immunomic new ch...        3851
# 3  model base design growth attenuated virus live...        4262
# 4  object simulation model model hypothetical dis...        3915
#
#    unique_words_count lang  label
# 0                1060   en      2
# 1                1019   en      2
# 2                1051   en      2
# 3                1029   en      2
# 4                1111   en      0

# %%
work_metadata.head()
# Out:
#    cord_uid                                       sha  \
# 0  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927
# 1  8qnrcgnk  faaf1022ccfe93b032c5608097a53543ba24aedb
# 2  d3cko4j2  40500cd7ae5b4e116e8b13e5408e7dfd96d43ab4
# 3  j3p1u80n  4c84dbfd01f7b2009ebed54376da8afcbcf1ec64
# 4  pk7pnmlo  61d9a0fe39f4e845c44a06787de6f5f033b998a3
#
#                                                title  \
# 0    Surfactant protein-D and pulmonary host defense
# 1  Heme oxygenase-1 and carbon monoxide in pulmon...
# 2  From Functional Genomics to Functional Immunom...
# 3    Model-Based Design of Growth-Attenuated Viruses
# 4  An object simulation model for modeling hypoth...
#
#                             doi       pmcid   pubmed_id  \
# 0                  10.1186/rr19    PMC59549  11667972.0
# 1         10.1186/1465-9921-4-7   PMC193681  12964953.0
# 2  10.1371/journal.pcbi.0020081  PMC1523295  16863395.0
# 3  10.1371/journal.pcbi.0020116  PMC1557587  16948530.0
# ...

# %% [markdown]
# __Word cloud function__

# %%
def cloud(df,cluster):
    stopwords = set(STOPWORDS)
    wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(df))
    fig = plt.figure(1)
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    filename = str(cluster)+".png"
    fig.savefig(filename, dpi=900)

# %% [markdown]
# # Word Cloud for Cluster 0

# %%
text0 = work_data[work_data['label'] == 0]

# %%
cloud(text1['text'],0)

# %% [markdown]
# # Word Cloud for Cluster 1

# %%
text1 = work_data[work_data['label'] == 1]

# %%
cloud(text2['text'],1)

# %% [markdown]
# # Word Cloud for Cluster 2

# %%
text2 = work_data[work_data['label'] == 2]

# %%
cloud(text3['text'],2)

# %% [markdown]
# # Word Cloud of Whole datasets

# %%
cloud(work_data['text'],4)
